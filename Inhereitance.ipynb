# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display_info(self):
        print(f"Name: {self.name}, Age: {self.age}")


class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.student_id = student_id

    def enroll_course(self, course):
        print(f"{self.name} has enrolled in {course}")

    def display_info(self):
        super().display_info()
        print(f"Student ID: {self.student_id}")


class Lecturer(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.employee_id = employee_id

    def teach_course(self, course):
        print(f"{self.name} is teaching {course}")


s1 = Student("Akyaa", 19, "UMaT/EL/2024/133")
l1 = Lecturer("Dr. Botchway", 45, "EMP001")

s1.display_info()
l1.display_info()

s1.enroll_course("Basic Electronics")
l1.teach_course("Python & OOP")
# Out:
# Name: Akyaa, Age: 19
# Student ID: UMaT/EL/2024/133
# Name: Dr. Botchway, Age: 45
# Akyaa has enrolled in Basic Electronics
# Dr. Botchway is teaching Python & OOP
